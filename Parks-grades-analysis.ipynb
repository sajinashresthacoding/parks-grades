# %%
##import libraries
import pandas as pd

# %%
df_PIP = pd.read_csv("data/RAW_PIP_GRADES.csv")
df_PIP
# Out:
#           Prop ID AMPSDistrict  Inspection ID  Season  Round  \
# 0            X028           04         135710  Summer      3
# 1        M010-241           13         135716  Summer      4
# 2         Q104-02           01         135720  Summer      4
# 3            X196           12         135735  Summer      4
# 4       B073-ZN05           19         135743  Summer      4
# ...           ...          ...            ...     ...    ...
# 128651  X092-ZN03           13         111707    Fall      2
# 128652  B082-ZN01           10         111708    Fall      2
# 128653  B073-ZN17           19         111710    Fall      2
# 128654  B073-ZN10           19         111711    Fall      2
# 128655  R065-ZN02           02         111712    Fall      2
#
#                           Date BeginInspection EndInspection  Inspection Year  \
# 0       07/15/2020 12:00:00 AM        03:00 PM      03:50 PM             2020
# ...

# %%
df_mp = pd.read_csv("data/RAW_PIP_map.csv")
df_mp
# Out:
#           PropNum      Prop ID Boro AMPSDistrict      Prop Name  \
# 0           B210T        B210T    B           10           Park
# 1           B210S        B210S    B           10           Park
# 2           B210R        B210R    B           10           Park
# 3     B210Q-BZ562  B210Q-BZ562    B           10  Coffey Square
# 4           B210Q        B210Q    B           10           Park
# ...           ...          ...  ...          ...            ...
# 6308         XZ89         XZ89    X           04    GREENSTREET
# 6309         XZ60         XZ60    X           09    GREENSTREET
# 6310         XZ58         XZ58    X           04    GREENSTREET
# 6311         XZ57         XZ57    X           03    GREENSTREET
# 6312        XZ56B        XZ56B    X           03    GREENSTREET
#
#           Site Name                             Prop Location  \
# 0              Park  N/B Gowanus Exwy. bet. 85 St. and 86 St.
# 1              Park  S/B Gowanus Exwy. bet. 85 St. and 86 St.
# ...

# %%
df_mp.query("ZipCode == '11377' | ZipCode == '11373' | ZipCode == '11372'")
# Out:
#      PropNum Prop ID Boro AMPSDistrict       Prop Name       Site Name  \
# 886    QZ267   QZ267    Q           03     Greenstreet     Greenstreet
# 887    QZ266   QZ266    Q           03     Greenstreet     Greenstreet
# 895    QZ261   QZ261    Q           03     Greenstreet     Greenstreet
# 896    QZ260   QZ260    Q           03     Greenstreet     Greenstreet
# 1865    Q013    Q013    Q           04  Veterans Grove  Veterans Grove
# ...      ...     ...  ...          ...             ...             ...
# 4849   QZ984   QZ984    Q           03     Greenstreet     Greenstreet
# 4850   QZ983   QZ983    Q           03     Greenstreet     Greenstreet
# 4858   QZ975   QZ975    Q           02             NaN             NaN
# 4884   QZ949   QZ949    Q           01     Greenstreet     Greenstreet
# 4966   QZ808   QZ808    Q           02     Greenstreet     Greenstreet
#
#                                           Prop Location  \
# 886                             34 Av Bet 89 St & 90 St
# ...

# %%
df_mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6313 entries, 0 to 6312
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PropNum           6313 non-null   object
#  1   Prop ID           6313 non-null   object
#  2   Boro              6313 non-null   object
#  3   AMPSDistrict      6313 non-null   object
#  4   Prop Name         6162 non-null   object
#  5   Site Name         6162 non-null   object
#  6   Prop Location     6311 non-null   object
#  7   Site Location     6311 non-null   object
#  8   Acres             6236 non-null   float64
#  9   Category          5866 non-null   object
#  10  Sub-Category      5041 non-null   object
#  11  Rated             6313 non-null   object
#  12  Reason Not Rated  1282 non-null   object
#  13  Council District  6299 non-null   object
#  14  ZipCode           6292 non-null   object
#  15  COMMUNITYBOARD    6304 non-null   object
# ...

# %%
df_mp["Prop ID"].nunique()
# Out:
# 6313

# %%
df_PIP["Prop ID"].nunique()
# Out:
# 3984

# %%
df_PIP["Prop ID"]
# Out:
# 0              X028
# 1          M010-241
# 2           Q104-02
# 3              X196
# 4         B073-ZN05
#             ...
# 128651    X092-ZN03
# 128652    B082-ZN01
# 128653    B073-ZN17
# 128654    B073-ZN10
# 128655    R065-ZN02
# Name: Prop ID, Length: 128656, dtype: object
