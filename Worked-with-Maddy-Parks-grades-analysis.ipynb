# %%
##import libraries
import pandas as pd

# %%
df_grades = pd.read_csv("data/RAW_PIP_GRADES.csv")
df_grades
# Out:
#           Prop ID AMPSDistrict  Inspection ID  Season  Round  \
# 0            X028           04         135710  Summer      3
# 1        M010-241           13         135716  Summer      4
# 2         Q104-02           01         135720  Summer      4
# 3            X196           12         135735  Summer      4
# 4       B073-ZN05           19         135743  Summer      4
# ...           ...          ...            ...     ...    ...
# 128651  X092-ZN03           13         111707    Fall      2
# 128652  B082-ZN01           10         111708    Fall      2
# 128653  B073-ZN17           19         111710    Fall      2
# 128654  B073-ZN10           19         111711    Fall      2
# 128655  R065-ZN02           02         111712    Fall      2
#
#                           Date BeginInspection EndInspection  Inspection Year  \
# 0       07/15/2020 12:00:00 AM        03:00 PM      03:50 PM             2020
# ...

# %%
##confirming that there is a number specific round to the seasons
df_grades[['Season', 'Round']].value_counts().unstack()
# Out:
# Round       0       1       2       3       4       5       6
# Season
# FALL      NaN     1.0     NaN     NaN     NaN     NaN     NaN
# Fall    244.0  5299.0  5282.0  5249.0  5277.0  5256.0  4972.0
# Spring  268.0  5308.0  5373.0  5197.0  5236.0  5208.0  5308.0
# Summer  292.0  5961.0  5871.0  5920.0  5670.0  5391.0  5267.0
# Winter  236.0  5108.0  5227.0  5075.0  4983.0  5141.0  5035.0
# spring    NaN     NaN     1.0     NaN     NaN     NaN     NaN

# %%
##df_grades.query('`Inspection Year` == "2022"')
# Out:
# Empty DataFrame
# Columns: [Prop ID, AMPSDistrict, Inspection ID, Season, Round, Date, BeginInspection, EndInspection, Inspection Year, inspector, inspector2, Overall Condition, Cleanliness, Safety Condition, Structural Condition, VisitorCount, Closed?, Comments, InspectionType, inspAddedDate]
# Index: []

# %%
df_grades['Inspection Year']
# Out:
# 0         2020
# 1         2020
# 2         2020
# 3         2020
# 4         2020
#           ...
# 128651    2017
# 128652    2017
# 128653    2017
# 128654    2017
# 128655    2017
# Name: Inspection Year, Length: 128656, dtype: int64

# %%
##this is just creating the filter
df_grades['Inspection Year'].eq(2022)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 128651    False
# 128652    False
# 128653    False
# 128654    False
# 128655    False
# Name: Inspection Year, Length: 128656, dtype: bool

# %%
##this basically takes ^ trues and falses and filters and keeps only stuff that is true
##this is putting the filter inside the dataframe
df_22 = df_grades[df_grades['Inspection Year'].eq(2022)].copy()
df_22
# Out:
#          Prop ID AMPSDistrict  Inspection ID  Season  Round       Date  \
# 1502     M042-02           12         165674  Summer      5 2022-08-15
# 1503        M180           12         165675  Summer      5 2022-08-15
# 1504   Q001-ZN10          07A         165690  Summer      5 2022-08-16
# 1505        Q370           08         165693  Summer      5 2022-08-16
# 1506      B223PD           01         165716  Summer      5 2022-08-16
# ...          ...          ...            ...     ...    ...        ...
# 31219  B126-ZN02           06         168188    Fall      4 2022-10-26
# 31220       B330           18         168195    Fall      4 2022-10-26
# 31221       X232           11         168196    Fall      4 2022-10-26
# 31222       B228           16         168199    Fall      4 2022-10-26
# 31223    X002-04           14         168201    Fall      4 2022-10-26
#
#       BeginInspection EndInspection  Inspection Year  inspector  inspector2  \
# ...

# %%
##all of queens' inspections in 2022
queens_filter = df_22["Prop ID"].str.startswith("Q")
df_q22 = df_22[queens_filter].copy()
df_q22
# Out:
#          Prop ID AMPSDistrict  Inspection ID  Season  Round       Date  \
# 1504   Q001-ZN10          07A         165690  Summer      5 2022-08-16
# 1505        Q370           08         165693  Summer      5 2022-08-16
# 1515       QZ279           03         166764  Summer      6 2022-08-19
# 1516   Q099-ZN21           15         166774  Summer      6 2022-08-20
# 1517        Q052           08         166776  Summer      6 2022-08-20
# ...          ...          ...            ...     ...    ...        ...
# 28845       Q284           01         161661  Spring      5 2022-04-29
# 28846       Q299           03         161662  Spring      5 2022-04-29
# 31213  Q099-ZN13           15         168203    Fall      4 2022-10-26
# 31214    Q099-54           15         168206    Fall      4 2022-10-26
# 31216  Q008-ZN01           13         168144    Fall      4 2022-10-25
#
#       BeginInspection EndInspection  Inspection Year  inspector  inspector2  \
# ...

# %%
##always do this to double check  you actually has the highest datetime because pd
##doesnt understand the concept of date and time
df_grades['Date'] = df_grades['Date'].apply(pd.to_datetime)

# %%
df_grades['Date'].max()
# Out:
# Timestamp('2022-10-31 00:00:00')

# %%
df_mp = pd.read_csv("data/PIP-MAPPED.csv")
df_mp
# Out:
#           PropNum      Prop ID Boro AMPSDistrict      Prop Name  \
# 0           B210T        B210T    B           10           Park
# 1           B210S        B210S    B           10           Park
# 2           B210R        B210R    B           10           Park
# 3     B210Q-BZ562  B210Q-BZ562    B           10  Coffey Square
# 4           B210Q        B210Q    B           10           Park
# ...           ...          ...  ...          ...            ...
# 6308         XZ89         XZ89    X           04    GREENSTREET
# 6309         XZ60         XZ60    X           09    GREENSTREET
# 6310         XZ58         XZ58    X           04    GREENSTREET
# 6311         XZ57         XZ57    X           03    GREENSTREET
# 6312        XZ56B        XZ56B    X           03    GREENSTREET
#
#           Site Name                             Prop Location  \
# 0              Park  N/B Gowanus Exwy. bet. 85 St. and 86 St.
# 1              Park  S/B Gowanus Exwy. bet. 85 St. and 86 St.
# ...
